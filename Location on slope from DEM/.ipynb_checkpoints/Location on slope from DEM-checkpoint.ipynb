# %%
import matplotlib.pyplot as plt
import matplotlib.image
import rasterio
import rasterio.plot
import rasterio.merge
import rasterio.mask
import geopandas as gpd
import cartopy.crs as ccrs
import numpy as np
import warnings
import time
import pandas as pd

# %%
import functions

# %% [markdown]
# ### Start  again by loading in all the gauge data
# Note: this is the output from the last cell in the "Slope steepness from DEM" notebook <br>
# Make sure to remove the 3 unfound gauges (filter < 99)

# %%
gauges = gpd.read_file("Gauge Data/Gauges-with-raster-id.shp",crs=4326)

# %%
gauges.query("raster_id < 99", inplace=True)
gauges
# Out:
#     src_id          station_na         station_fi         historic_c  \
# 0    00003           FAIR ISLE          fair-isle           shetland
# 3    00023            KIRKWALL           kirkwall             orkney
# 4    00032        WICK AIRPORT       wick-airport          caithness
# 5    00040             CASSLEY            cassley         sutherland
# 6    00044     ALTNAHARRA NO 2    altnaharra-no-2         sutherland
# ..     ...                 ...                ...                ...
# 363  24218    HARTPURY COLLEGE   hartpury-college    gloucestershire
# 364  24219     MANNINGTON HALL    mannington-hall            norfolk
# 365  57118  BUTE: ROTHESAY NO2  bute-rothesay-no2          buteshire
# 366  57233         MARGAM NO 2        margam-no-2     glamorganshire
# 367  57267     ACHILTIBUIE NO2    achiltibuie-no2  ross-and-cromarty
#
#      station_la  station_lo  station_el  first_year  last_year  raster_id  \
# 0        59.526      -1.630          57        1974       2020          4
# 3        58.953      -2.901          26        1957       2020          4
# 4        58.454      -3.090          36        1930       2020          4
# 5        58.168      -4.727          99        1999       2020          4
# 6        58.288      -4.442          81        1993       2020          4
# ..          ...         ...         ...         ...        ...        ...
# 363      51.904      -2.312          41        1998       2020          1
# 364      52.844       1.179          30        1999       2020          0
# 365      55.825      -5.056          36        2013       2020          5
# 366      51.555      -3.721          40        2013       2020          1
# 367      58.015      -5.336          49        2013       2020          5
#
#                       geometry
# 0    POINT (-1.63000 59.52600)
# 3    POINT (-2.90100 58.95300)
# 4    POINT (-3.09000 58.45400)
# 5    POINT (-4.72700 58.16800)
# 6    POINT (-4.44200 58.28800)
# ..                         ...
# 363  POINT (-2.31200 51.90400)
# 364   POINT (1.17900 52.84400)
# 365  POINT (-5.05600 55.82500)
# 366  POINT (-3.72100 51.55500)
# 367  POINT (-5.33600 58.01500)
#
# [365 rows x 11 columns]

# %% [markdown]
# The cropped data is indexed by the filenames first so still need those

# %%
filenames = []
with open("Cropped Data/filenames.txt") as fin:
    for line in fin:
        filenames.append(line.strip())
# filenames

# %%
UK = filenames[68:69] + filenames[80:83] + filenames[95:97]
print(UK)
# Out:
# ['n50e000_dem', 'n50w005_dem', 'n50w010_dem', 'n50w015_dem', 'n55w005_dem', 'n55w010_dem']

# %% [markdown]
# #### Up until now  main focus has been on a slope of given length
# now, first consider a close by slope e.g. 1 - 5px and then look how long this continues for.

# %%
number_px = 1
instance = functions.Raster_Location_OnSlope(gauges, UK, number_px)

# %% [markdown]
# #### This is a given array

# %%
print(f'Gauge height: {instance.get_array_given_orientation(0, "ns")[0][30]}, array:')
instance.get_array_given_orientation(0, "ns")[0]
# Out:
# Gauge height: 57, array:
# array([-32768,    126,    139,    154,    176,    191,    190,    172,
#           156,    151,    143,    134,    124,    120,    112,    101,
#            90,     78,     75,     73,     70,     66,     62,     68,
#            65,     58,     59,     61,     56,     56,     57,     57,
#            53,     49,     41,     35,     44,     49,     38,     25,
#            17,     35,     43,     22,      4, -32768, -32768, -32768,
#        -32768, -32768, -32768, -32768, -32768, -32768, -32768, -32768,
#        -32768, -32768, -32768, -32768, -32768], dtype=int16)

# %% [markdown]
# #### ant this is its steepness
# here 'n_px=5' is used

# %%
instance.slope_steepness(1, "ns")
# Out:
# -18.84516008862999

# %% [markdown]
# #### we can then look just outside the previous range made used to caculate the steepness
# Each on both sides taking the next segment of size equal to the stepsize

# %%
plt.figure(figsize=(7,7))
plt.imshow(matplotlib.image.imread("Figures/Profile of slope around gauge n0ns - showing steps.jpg"))
plt.axis("off");

# %% [markdown]
# #### consider this case:

# %%
functions.plotting(gauges, UK, 5).plot_gauge(0, "all")

# %% [markdown]
# #### a function was written comparing the left and right slope, returning what it is
# again the amount of pixels matters, 5px seems to work

# %%
label = ["ew","ns","nw-se","ne-sw"]
for i in range(365):
    out = functions.Raster_Location_OnSlope(gauges, UK, 3).get_location_on_slope(i)
    if None in out:
        functions.plotting(gauges, UK, 5).plot_gauge(i, label[out.index(None)])
    print(i,out)
# Out:
# 0 ['Ridge', 'slope', 'slope', 'Ridge']
# 1 ['Ridge', 'Slope', 'Slope', 'Slope']
# 2 ['Slope', 'slope', 'slope', 'Ridge']
# 3 ['slope', 'Slope', 'Slope', 'Slope']
# 4 ['Valley', 'Valley', 'slope', 'Valley']
# 5 ['Slope', 'slope', 'Valley', 'Valley']
# C:\Users\david\Documents\@@ Python\Jaar 4\Q3\Are-rain-gauges-in-the-right-place\Location on slope from DEM\functions.py:114: RuntimeWarning: overflow encountered in short_scalars
#   rise = item - array[index+1]
# 6 ['Valley', 'Slope', 'Slope', 'Valley']
# 7 ['Ridge', 'slope', 'Ridge', 'slope']
# 8 ['Slope', 'Slope', 'Slope', 'Slope']
# 9 ['slope', 'Valley', 'Valley', 'Valley']
# 10 ['Ridge', 'Slope', 'Ridge', 'Slope']
# 11 ['Valley', 'slope', 'Valley', 'Slope']
# 12 ['Slope', 'Slope', 'Slope', 'Slope']
# 13 ['Valley', 'Valley', 'Valley', 'Slope']
# 14 ['slope', 'slope', 'slope', 'Valley']
# -1.0002367179521192 0.0
# 15 ['slope', None, 'Valley', 'Slope']
# 16 ['Valley', 'Valley', 'Valley', 'slope']
# 17 ['Valley', 'Valley', 'Valley', 'Valley']
# 18 ['slope', 'Slope', 'Slope', 'Valley']
# 19 ['Valley', 'slope', 'slope', 'slope']
# 20 ['Valley', 'Slope', 'Slope', 'Ridge']
# 21 ['slope', 'Slope', 'Slope', 'Slope']
# 22 ['slope', 'Slope', 'Valley', 'Slope']
# 23 ['Slope', 'Ridge', 'Ridge', 'Ridge']
# 24 ['Slope', 'Valley', 'Valley', 'Valley']
# 25 ['slope', 'Slope', 'Slope', 'Slope']
# 0.0 1.950267602852875
# 26 ['slope', 'Ridge', 'Ridge', None]
# 27 ['Ridge', 'slope', 'slope', 'slope']
# 28 ['slope', 'slope', 'slope', 'slope']
# 29 ['Valley', 'Valley', 'Valley', 'Valley']
# 30 ['slope', 'Slope', 'Ridge', 'Slope']
# 31 ['slope', 'Ridge', 'slope', 'Slope']
# 32 ['slope', 'Ridge', 'slope', 'Slope']
# 33 ['Valley', 'Slope', 'Slope', 'Slope']
# 34 ['slope', 'Ridge', 'Ridge', 'Flat']
# 35 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# 36 ['slope', 'Ridge', 'Ridge', 'Slope']
# 37 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# 38 ['Valley', 'Valley', 'Ridge', 'Ridge']
# 39 ['Valley', 'slope', 'slope', 'Valley']
# 40 ['slope', 'slope', 'Valley', 'Valley']
# 41 ['slope', 'Ridge', 'Ridge', 'Ridge']
# 42 ['slope', 'slope', 'Valley', 'Valley']
# 43 ['slope', 'slope', 'slope', 'Valley']
# 44 ['Slope', 'Flat', 'Ridge', 'slope']
# 0.8945846911678614 0.0
# 0.8945846911678614 0.0
# 45 ['Slope', None, None, 'Flat']
# 46 ['Valley', 'Ridge', 'Valley', 'slope']
# 47 ['Slope', 'Valley', 'Valley', 'Valley']
# 48 ['Ridge', 'Slope', 'Slope', 'Slope']
# 49 ['slope', 'Valley', 'Valley', 'Valley']
# 50 ['Ridge', 'Slope', 'Slope', 'Ridge']
# 51 ['slope', 'Valley', 'Slope', 'Valley']
# 52 ['slope', 'slope', 'slope', 'slope']
# 53 ['Slope', 'Slope', 'Slope', 'Valley']
# 54 ['Ridge', 'Ridge', 'slope', 'Ridge']
# 55 ['Slope', 'Slope', 'Ridge', 'Slope']
# 56 ['Slope', 'Slope', 'Slope', 'Ridge']
# 57 ['Slope', 'slope', 'Valley', 'Ridge']
# 58 ['Ridge', 'slope', 'slope', 'Valley']
# 59 ['slope', 'Slope', 'Ridge', 'Ridge']
# 60 ['slope', 'Ridge', 'Slope', 'Slope']
# 61 ['slope', 'Ridge', 'Ridge', 'Ridge']
# 62 ['slope', 'Slope', 'slope', 'Slope']
# 63 ['Valley', 'Ridge', 'Slope', 'Valley']
# 64 ['slope', 'Ridge', 'Slope', 'Slope']
# 65 ['slope', 'Slope', 'slope', 'Slope']
# 66 ['slope', 'Ridge', 'slope', 'Ridge']
# 67 ['Ridge', 'Slope', 'Ridge', 'Ridge']
# 68 ['slope', 'Ridge', 'Slope', 'Slope']
# 69 ['Ridge', 'slope', 'Ridge', 'slope']
# 70 ['Ridge', 'Valley', 'Slope', 'Ridge']
# 71 ['slope', 'slope', 'slope', 'Ridge']
# 72 ['Ridge', 'Valley', 'Ridge', 'Ridge']
# 73 ['Valley', 'Valley', 'Ridge', 'Valley']
# 74 ['slope', 'slope', 'Flat', 'slope']
# 75 ['slope', 'slope', 'slope', 'slope']
# 76 ['slope', 'Valley', 'Valley', 'Valley']
# 77 ['Valley', 'Valley', 'slope', 'slope']
# 78 ['Slope', 'slope', 'Slope', 'slope']
# 79 ['Slope', 'Slope', 'Valley', 'Ridge']
# 80 ['Valley', 'Ridge', 'slope', 'Ridge']
# 81 ['Slope', 'Slope', 'Slope', 'Slope']
# 82 ['slope', 'Slope', 'Slope', 'Slope']
# 83 ['slope', 'Ridge', 'Ridge', 'Ridge']
# 84 ['Ridge', 'slope', 'Flat', 'Ridge']
# 85 ['slope', 'Valley', 'slope', 'Valley']
# 86 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# 87 ['Valley', 'Slope', 'Valley', 'slope']
# 88 ['slope', 'slope', 'slope', 'Ridge']
# 89 ['Slope', 'Valley', 'slope', 'Valley']
# 90 ['Valley', 'Valley', 'Valley', 'Valley']
# 91 ['slope', 'Valley', 'Valley', 'Ridge']
# 92 ['Ridge', 'Ridge', 'Slope', 'Ridge']
# 93 ['slope', 'Slope', 'Valley', 'Slope']
# 94 ['slope', 'Slope', 'Slope', 'Slope']
# 95 ['Ridge', 'Slope', 'Slope', 'Slope']
# 96 ['Valley', 'Slope', 'Slope', 'Slope']
# 97 ['slope', 'Ridge', 'Ridge', 'Ridge']
# 98 ['Ridge', 'slope', 'Ridge', 'Valley']
# 99 ['Ridge', 'Valley', 'slope', 'Ridge']
# 100 ['Ridge', 'slope', 'slope', 'slope']
# 101 ['Valley', 'Slope', 'slope', 'Slope']
# 102 ['slope', 'Slope', 'Slope', 'Slope']
# 103 ['Ridge', 'slope', 'Ridge', 'Valley']
# 104 ['Ridge', 'slope', 'slope', 'Ridge']
# 105 ['Ridge', 'Valley', 'Slope', 'Valley']
# 106 ['slope', 'slope', 'slope', 'Ridge']
# 107 ['Valley', 'Valley', 'Valley', 'slope']
# 108 ['Ridge', 'slope', 'slope', 'slope']
# 109 ['slope', 'Ridge', 'slope', 'Ridge']
# 110 ['Ridge', 'Ridge', 'slope', 'Ridge']
# 111 ['Ridge', 'Ridge', 'Slope', 'Ridge']
# 112 ['Flat', 'Ridge', 'Ridge', 'slope']
# 113 ['slope', 'Slope', 'Valley', 'Slope']
# 114 ['Slope', 'Ridge', 'Ridge', 'Valley']
# 115 ['Valley', 'slope', 'Ridge', 'Valley']
# 116 ['Slope', 'slope', 'Slope', 'Ridge']
# 117 ['Slope', 'Ridge', 'Slope', 'Ridge']
# 118 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# 119 ['Ridge', 'Valley', 'slope', 'slope']
# 120 ['slope', 'Valley', 'Ridge', 'Slope']
# 121 ['Ridge', 'Ridge', 'Ridge', 'Slope']
# 122 ['Slope', 'Ridge', 'Slope', 'Ridge']
# 123 ['slope', 'Slope', 'Valley', 'Ridge']
# 124 ['Ridge', 'Ridge', 'Ridge', 'slope']
# 125 ['slope', 'Valley', 'Valley', 'slope']
# 126 ['Ridge', 'slope', 'slope', 'slope']
# 127 ['Ridge', 'Ridge', 'Slope', 'slope']
# 128 ['slope', 'Slope', 'Slope', 'Ridge']
# 129 ['Slope', 'slope', 'Ridge', 'slope']
# 130 ['Slope', 'Ridge', 'Ridge', 'slope']
# 131 ['Ridge', 'Slope', 'Slope', 'Slope']
# 132 ['Slope', 'slope', 'Valley', 'Valley']
# 133 ['Valley', 'Slope', 'Valley', 'Slope']
# 134 ['Ridge', 'Valley', 'Ridge', 'slope']
# 135 ['Slope', 'slope', 'slope', 'slope']
# 136 ['Ridge', 'Ridge', 'Ridge', 'slope']
# 137 ['Ridge', 'slope', 'slope', 'Ridge']
# 138 ['Valley', 'Valley', 'slope', 'Valley']
# 139 ['slope', 'Ridge', 'slope', 'Ridge']
# 140 ['slope', 'Slope', 'Slope', 'Slope']
# 141 ['slope', 'Slope', 'Valley', 'Slope']
# 0.0 0.9025112242285244
# 142 ['Slope', 'slope', None, 'Ridge']
# 143 ['Ridge', 'Ridge', 'Ridge', 'Slope']
# 144 ['Slope', 'slope', 'slope', 'slope']
# 145 ['Ridge', 'Valley', 'Valley', 'Valley']
# 146 ['slope', 'Valley', 'Valley', 'slope']
# 147 ['slope', 'Ridge', 'Slope', 'Ridge']
# 148 ['Slope', 'Ridge', 'slope', 'slope']
# 149 ['Slope', 'Valley', 'Valley', 'slope']
# 150 ['Valley', 'slope', 'slope', 'slope']
# 151 ['Slope', 'Valley', 'Valley', 'Valley']
# 152 ['slope', 'slope', 'slope', 'slope']
# 153 ['Slope', 'slope', 'slope', 'slope']
# 154 ['Slope', 'Slope', 'Slope', 'Slope']
# 155 ['Slope', 'Slope', 'Slope', 'Ridge']
# 156 ['slope', 'Ridge', 'slope', 'Ridge']
# 157 ['slope', 'slope', 'slope', 'slope']
# 158 ['Valley', 'Ridge', 'Ridge', 'slope']
# 159 ['Valley', 'Valley', 'slope', 'Valley']
# 160 ['slope', 'Valley', 'Valley', 'Valley']
# 161 ['Slope', 'slope', 'slope', 'slope']
# 0.858110827697833 0.0
# 162 [None, 'slope', 'slope', 'Ridge']
# 163 ['slope', 'Ridge', 'Ridge', 'Valley']
# 0.0 -5.956578967729272
# 164 ['Flat', 'Valley', 'Valley', None]
# 165 ['Ridge', 'Ridge', 'Valley', 'Slope']
# 166 ['Valley', 'Slope', 'Slope', 'Valley']
# 167 ['slope', 'Valley', 'Slope', 'Valley']
# 168 ['Ridge', 'Slope', 'Ridge', 'Ridge']
# 169 ['Slope', 'Flat', 'Ridge', 'Valley']
# 170 ['Valley', 'Ridge', 'Ridge', 'slope']
# 171 ['Slope', 'Ridge', 'Ridge', 'Ridge']
# 172 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# 173 ['Valley', 'Slope', 'slope', 'Slope']
# 174 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# 175 ['Valley', 'Valley', 'slope', 'Valley']
# 176 ['Slope', 'Ridge', 'Ridge', 'Ridge']
# 177 ['Slope', 'Ridge', 'Slope', 'Ridge']
# 178 ['slope', 'Valley', 'Slope', 'Valley']
# 179 ['Slope', 'Slope', 'Valley', 'Slope']
# 180 ['Slope', 'slope', 'Valley', 'slope']
# 181 ['Slope', 'Ridge', 'Slope', 'Ridge']
# 182 ['Valley', 'slope', 'Valley', 'slope']
# 183 ['Ridge', 'slope', 'slope', 'slope']
# 184 ['Slope', 'Valley', 'Valley', 'slope']
# 185 ['Ridge', 'Ridge', 'Ridge', 'Slope']
# 186 ['Slope', 'Slope', 'Slope', 'Slope']
# 187 ['slope', 'Ridge', 'Ridge', 'Ridge']
# 188 ['slope', 'Valley', 'Valley', 'slope']
# 189 ['Slope', 'Ridge', 'Ridge', 'Valley']
# 190 ['Slope', 'Slope', 'Slope', 'Valley']
# 191 ['Slope', 'Ridge', 'Slope', 'Valley']
# 192 ['Ridge', 'slope', 'Ridge', 'slope']
# 193 ['Ridge', 'Slope', 'Slope', 'Slope']
# 194 ['slope', 'Ridge', 'slope', 'Ridge']
# 195 ['slope', 'Slope', 'Ridge', 'Ridge']
# 196 ['Ridge', 'slope', 'Ridge', 'Valley']
# 197 ['Slope', 'slope', 'Slope', 'Valley']
# 198 ['Slope', 'Ridge', 'slope', 'Valley']
# 199 ['Slope', 'Ridge', 'Ridge', 'Ridge']
# -2.5967310415442006 0.0
# 200 ['slope', 'Slope', 'Ridge', None]
# 201 ['Slope', 'Slope', 'Ridge', 'Slope']
# 202 ['Slope', 'Slope', 'Slope', 'Slope']
# 203 ['Slope', 'slope', 'slope', 'Ridge']
# 0.0 -0.8861096245791508
# 204 [None, 'Valley', 'Flat', 'Slope']
# 205 ['Slope', 'Valley', 'Slope', 'Slope']
# 206 ['slope', 'Ridge', 'Ridge', 'Ridge']
# 207 ['Flat', 'slope', 'Valley', 'Flat']
# 208 ['Valley', 'slope', 'Ridge', 'slope']
# 209 ['Valley', 'Slope', 'Slope', 'Valley']
# 210 ['Valley', 'Valley', 'Ridge', 'Valley']
# 211 ['Ridge', 'slope', 'Ridge', 'slope']
# 212 ['Ridge', 'Ridge', 'Slope', 'Ridge']
# 213 ['slope', 'Slope', 'slope', 'Slope']
# 214 ['Slope', 'Ridge', 'Slope', 'slope']
# 215 ['Valley', 'Valley', 'Valley', 'Valley']
# 216 ['Valley', 'Slope', 'Valley', 'Slope']
# 217 ['Slope', 'Slope', 'Valley', 'Slope']
# 218 ['Slope', 'slope', 'Valley', 'slope']
# 219 ['Ridge', 'Slope', 'Slope', 'Slope']
# 220 ['slope', 'slope', 'slope', 'slope']
# 221 ['slope', 'Ridge', 'Ridge', 'Ridge']
# 222 ['slope', 'slope', 'slope', 'Ridge']
# -0.8854461838582626 0.0
# 223 [None, 'Ridge', 'slope', 'Ridge']
# 224 ['Valley', 'Slope', 'Ridge', 'slope']
# 225 ['Ridge', 'slope', 'slope', 'Ridge']
# 226 ['slope', 'slope', 'Ridge', 'slope']
# 227 ['slope', 'Ridge', 'Ridge', 'Ridge']
# 228 ['Ridge', 'Slope', 'Slope', 'slope']
# 229 ['slope', 'Slope', 'slope', 'Slope']
# 230 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# -0.9451590673130904 0.0
# 0.0 1.8903181346261808
# 0.0 -0.9451590673130904
# 231 [None, None, None, 'Ridge']
# 232 ['slope', 'Slope', 'Ridge', 'Flat']
# 233 ['Slope', 'Ridge', 'Valley', 'Ridge']
# 234 ['Ridge', 'slope', 'Valley', 'Valley']
# 235 ['slope', 'Ridge', 'Slope', 'slope']
# 236 ['Ridge', 'Ridge', 'Slope', 'Ridge']
# 237 ['slope', 'Valley', 'Valley', 'Slope']
# 238 ['Ridge', 'slope', 'slope', 'slope']
# 239 ['Slope', 'Ridge', 'Slope', 'slope']
# 240 ['Slope', 'slope', 'slope', 'slope']
# 241 ['slope', 'Ridge', 'slope', 'Slope']
# 242 ['Slope', 'Valley', 'Valley', 'Slope']
# 243 ['slope', 'Ridge', 'Slope', 'Ridge']
# 244 ['Valley', 'Slope', 'Valley', 'Slope']
# 245 ['Valley', 'Valley', 'Valley', 'Valley']
# 246 ['slope', 'Ridge', 'Slope', 'Slope']
# 247 ['Valley', 'Slope', 'Ridge', 'Slope']
# 248 ['Ridge', 'Slope', 'Slope', 'Ridge']
# 0.0 0.9657001974916399
# 249 [None, 'Ridge', 'Ridge', 'slope']
# 250 ['slope', 'Ridge', 'Slope', 'slope']
# 251 ['slope', 'Ridge', 'Ridge', 'Valley']
# 252 ['slope', 'Valley', 'slope', 'Valley']
# 253 ['Slope', 'Slope', 'Slope', 'Slope']
# 254 ['slope', 'slope', 'slope', 'slope']
# 255 ['Valley', 'Flat', 'slope', 'Valley']
# 256 ['Slope', 'slope', 'slope', 'slope']
# 257 ['Slope', 'slope', 'Valley', 'Valley']
# 258 ['Slope', 'slope', 'Valley', 'Ridge']
# -1.8297069425838055 0.0
# 259 ['slope', None, 'Flat', 'Ridge']
# 260 ['Flat', 'slope', 'Valley', 'slope']
# 261 ['Slope', 'Ridge', 'Slope', 'Ridge']
# 262 ['Valley', 'Ridge', 'Slope', 'Ridge']
# 263 ['Slope', 'Ridge', 'Slope', 'Ridge']
# 264 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# 265 ['Valley', 'Ridge', 'slope', 'Slope']
# 266 ['slope', 'slope', 'slope', 'Valley']
# 267 ['Slope', 'Ridge', 'Ridge', 'slope']
# 268 ['Valley', 'slope', 'slope', 'Valley']
# 269 ['Slope', 'Ridge', 'Ridge', 'Ridge']
# 270 ['Ridge', 'Slope', 'Slope', 'Slope']
# 271 ['slope', 'slope', 'slope', 'slope']
# 272 ['slope', 'Ridge', 'Flat', 'Flat']
# 273 ['slope', 'Valley', 'Valley', 'Valley']
# 1.738692447031406 0.0
# 274 ['Slope', None, 'Valley', 'slope']
# 275 ['Valley', 'slope', 'slope', 'slope']
# 276 ['slope', 'Slope', 'Slope', 'Slope']
# 277 ['slope', 'slope', 'Flat', 'Flat']
# 278 ['slope', 'slope', 'slope', 'slope']
# 279 ['slope', 'Slope', 'Slope', 'Valley']
# 280 ['Valley', 'slope', 'Valley', 'Valley']
# 281 ['Ridge', 'slope', 'Ridge', 'Ridge']
# 282 ['Valley', 'slope', 'Valley', 'Valley']
# 283 ['Slope', 'slope', 'Valley', 'slope']
# 284 ['Slope', 'Valley', 'Slope', 'Slope']
# 285 ['Valley', 'slope', 'Ridge', 'Slope']
# 286 ['Valley', 'Slope', 'Valley', 'Ridge']
# 287 ['slope', 'Valley', 'Slope', 'slope']
# 288 ['Slope', 'Slope', 'Slope', 'Slope']
# 289 ['Slope', 'Ridge', 'Ridge', 'Ridge']
# 290 ['Ridge', 'Slope', 'Slope', 'Ridge']
# 291 ['Ridge', 'slope', 'slope', 'slope']
# 292 ['Ridge', 'Slope', 'Valley', 'Valley']
# 293 ['Slope', 'Slope', 'Valley', 'slope']
# 294 ['Ridge', 'Valley', 'Valley', 'Valley']
# 295 ['slope', 'Valley', 'Valley', 'Valley']
# 296 ['Slope', 'Slope', 'Slope', 'slope']
# 0.0 -1.7828050706824818
# 297 ['Slope', 'Slope', 'Valley', None]
# 298 ['Slope', 'slope', 'slope', 'slope']
# 299 ['Valley', 'slope', 'slope', 'Valley']
# 0.0 -28587.119700742816
# 300 ['Valley', 'Flat', 'Flat', None]
# 301 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# 302 ['Flat', 'Valley', 'Valley', 'slope']
# 303 ['Slope', 'Slope', 'Valley', 'Slope']
# 304 ['Valley', 'Slope', 'Slope', 'Slope']
# 305 ['Valley', 'slope', 'Valley', 'slope']
# 306 ['Valley', 'Valley', 'Valley', 'Slope']
# 307 ['Slope', 'Valley', 'Valley', 'Valley']
# 308 ['Ridge', 'slope', 'slope', 'slope']
# 309 ['Slope', 'Valley', 'slope', 'slope']
# 310 ['Slope', 'Slope', 'Slope', 'Slope']
# 311 ['Slope', 'Ridge', 'Slope', 'slope']
# 312 ['Ridge', 'Ridge', 'Slope', 'slope']
# 313 ['Slope', 'Slope', 'Slope', 'Valley']
# 314 ['Valley', 'Valley', 'Valley', 'slope']
# 315 ['slope', 'Valley', 'Valley', 'Slope']
# 316 ['Valley', 'Valley', 'Slope', 'Slope']
# 317 ['Ridge', 'Slope', 'Slope', 'Slope']
# 318 ['Valley', 'slope', 'Valley', 'slope']
# 319 ['Ridge', 'Ridge', 'Slope', 'Ridge']
# 320 ['Valley', 'slope', 'slope', 'slope']
# 321 ['Ridge', 'Slope', 'Ridge', 'Slope']
# 322 ['Ridge', 'Ridge', 'Slope', 'slope']
# 323 ['Slope', 'Valley', 'Valley', 'Valley']
# 324 ['slope', 'Flat', 'slope', 'Slope']
# 325 ['slope', 'slope', 'Valley', 'Valley']
# 326 ['Valley', 'Ridge', 'Ridge', 'Slope']
# 327 ['Ridge', 'Slope', 'Slope', 'Slope']
# 328 ['Ridge', 'slope', 'Slope', 'slope']
# 329 ['Ridge', 'Valley', 'Valley', 'Valley']
# 330 ['Slope', 'Ridge', 'Ridge', 'Slope']
# 331 ['slope', 'Valley', 'Valley', 'Slope']
# 332 ['slope', 'slope', 'Valley', 'slope']
# 333 ['Ridge', 'Ridge', 'Valley', 'slope']
# 334 ['slope', 'Slope', 'slope', 'Slope']
# 335 ['Valley', 'Slope', 'Valley', 'Slope']
# 336 ['Slope', 'slope', 'slope', 'slope']
# 337 ['Ridge', 'Valley', 'slope', 'slope']
# 338 ['Ridge', 'slope', 'slope', 'Ridge']
# 339 ['slope', 'Ridge', 'Valley', 'Valley']
# 340 ['slope', 'slope', 'slope', 'slope']
# 341 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# 342 ['Valley', 'Valley', 'Valley', 'Slope']
# 343 ['slope', 'Ridge', 'Ridge', 'Ridge']
# 344 ['Slope', 'slope', 'Ridge', 'slope']
# 345 ['Ridge', 'slope', 'Slope', 'slope']
# 346 ['slope', 'Ridge', 'Valley', 'Slope']
# 347 ['slope', 'Valley', 'Valley', 'Valley']
# 348 ['Valley', 'slope', 'slope', 'slope']
# 349 ['Valley', 'Slope', 'Ridge', 'Ridge']
# 350 ['Slope', 'Slope', 'Slope', 'Slope']
# 351 ['Valley', 'Valley', 'Valley', 'Slope']
# 352 ['Slope', 'Slope', 'Slope', 'slope']
# 353 ['slope', 'Ridge', 'slope', 'Ridge']
# 354 ['slope', 'slope', 'slope', 'Valley']
# 355 ['slope', 'slope', 'slope', 'slope']
# 356 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# 357 ['slope', 'slope', 'Ridge', 'slope']
# 358 ['Slope', 'Slope', 'Slope', 'Slope']
# 359 ['Ridge', 'Ridge', 'Valley', 'Ridge']
# 360 ['Ridge', 'Ridge', 'Ridge', 'Ridge']
# 361 ['slope', 'Valley', 'Slope', 'Valley']
# 362 ['Slope', 'Slope', 'Slope', 'slope']
# 363 ['Slope', 'slope', 'Slope', 'slope']
# 364 ['Slope', 'slope', 'Ridge', 'slope']

# %%
functions.plotting(gauges, UK, 5).plot_varying_n_px([45])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 functions.plotting(gauges, UK, 5).plot_varying_n_px([45])
#
# File ~\Documents\@@ Python\Jaar 4\Q3\Are-rain-gauges-in-the-right-place\Location on slope from DEM\functions.py:522, in plotting.plot_varying_n_px(self, lst, subplots, save)
#     518     n_px = j
#     520     ## again little jank but will do
# --> 522     lst.append(self.slope_steepness_all_orientations_varypxs(i, n_px))
#     523 if subplots:
#     524     fig, ax = plt.subplots(1,figsize=(4,4))
#
# File ~\Documents\@@ Python\Jaar 4\Q3\Are-rain-gauges-in-the-right-place\Location on slope from DEM\functions.py:485, in plotting.slope_steepness_all_orientations_varypxs(self, n, n_px)
#     483 lst = []
#     484 for orientation in self.label:
# --> 485     lst.append(self.slope_steepness_varypxs(n, n_px, orientation))
#     486 return lst
#
# File ~\Documents\@@ Python\Jaar 4\Q3\Are-rain-gauges-in-the-right-place\Location on slope from DEM\functions.py:506, in plotting.slope_steepness_varypxs(self, n, n_px, kind)
#     503         rise = item - array_cropped[index+1]
#     504         diff.append(rise)
# --> 506 return ( (sum(diff)/(len(diff)-1)) / self.distance_between_px(n)) * 100
#
# AttributeError: 'plotting' object has no attribute 'distance_between_px'

# %%
rint(f'Gauge height: {instance.get_array_given_orientation(0, "ns")[0][30]}, array:')
instance.get_array_given_orientation(0, "ns")[0]

# %% [markdown]
# #### looking at when slope steepness changes:
# i'll get back to this, the cells are roling again, which is what we want

# %%
instance.get_array_step(0,"ns",1, "right", True),\
instance.get_array_step(0,"ns",2, "right", True),\
instance.get_array_step(0,"ns",3, "right", True),\
instance.get_array_step(0,"ns",1, "left", True),\
instance.get_array_step(0,"ns",2, "left", True),\
instance.get_array_step(0,"ns",3, "left", True)

# %%
instance.change_slope_steepness(1, "ew", 1, 5)
